# %%
# Permet de load le csv des données récoltées pour afficher proprement le dataset

import pandas as pd

df = pd.read_csv("../Donnees/cleaned_data.csv")
df = df.set_index("hltb_id")

df
# Out:
# c:\Users\rapha\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                                           title  rating  retirement  \
# hltb_id
# 38                                     10000000      73         9.0
# 50       18 Wheels of Steel: American Long Haul      53        23.1
# 66                                         3079      27        23.8
# 79                                     40 Winks      57         9.6
# 95                                 7 Wonders II      60         8.4
# ...                                         ...     ...         ...
# 37895                          Insanity Clicker      60        32.5
# 37905                             Ninja Stealth      39         5.2
# 37940                               Solitairica      68         9.7
# 37950                          Agents of Mayhem      62         7.1
# 37972                Trials of the Blood Dragon      65         5.7
#
#                                      platform  \
# hltb_id
# 38                           ['Mobile', 'PC']
# 50                                     ['PC']
# 66                                     ['PC']
# 79       ['Nintendo 64', 'PC', 'PlayStation']
# 95                      ['Nintendo DS', 'PC']
# ...                                       ...
# 37895                                  ['PC']
# 37905                                  ['PC']
# 37940                        ['Mobile', 'PC']
# 37950     ['PC', 'PlayStation 4', 'Xbox One']
# 37972     ['PC', 'PlayStation 4', 'Xbox One']
#
#                                                      genre  date       time  \
# hltb_id
# 38                              ['Puzzle', 'Role-Playing']  2012   6.316667
# 50                                          ['Simulation']  2007  20.916667
# 66       ['First-Person', 'Action', 'Open World', 'Role...  2011   3.400000
# 79                                            ['Platform']  1999   7.166667
# 95                                              ['Puzzle']  2008   6.500000
# ...                                                    ...   ...        ...
# 37895                                  ['Point-and-Click']  2016  69.050000
# 37905                                         ['Strategy']  2016   1.616667
# 37940                         ['Role-Playing', 'Strategy']  2016   8.066667
# 37950                                           ['Action']  2017  16.616667
# 37972    ['Third-Person', 'Action', 'Arcade', 'Platform...  2016   3.383333
#
#            price  pourcentage_pos  review_count  rating_value  \
# hltb_id
# 38        4.5908               90          1666           9.0
# 50        9.1908               75           387           7.0
# 66        4.5908               52           303           6.0
# 79       11.9508               70            30           7.0
# 95        9.1908               88            54           9.0
# ...          ...              ...           ...           ...
# 37895     0.0000               72          2842           6.0
# 37905     0.9900               76           742           7.0
# 37940     9.9900               82           310           9.0
# 37950    29.9900               45          3110           6.0
# 37972    14.9900               68           189           6.0
#
#                                                description  twenty_four_hours  \
# hltb_id
# 38       10000000 est un jeu de combinaison Dungeon-RPG...                  2
# 50       Le rêve américain au volant d'un semi-remorque...                  4
# 66       3079 is a futuristic, open-world action first-...                  0
# 79       FIGHT AS A NINJA. TRANSFORM INTO A ROBOT...OR ...                  0
# 95       Avec la série des jeux 7 Wonders, retournez à ...                 13
# ...                                                    ...                ...
# 37895    Been looking for the thrill? Then you've come ...                 50
# 37905    As a ninja you will need to be always hiden in...                  5
# 37940    Solitairica takes RPG combat and challenging r...                  9
# 37950    Agents of MAYHEM est le nouveau jeu d'action à...                 19
# 37972    2019 – PRÉSENT Dans un monde où les Dragons de...                  0
#
#          all_time
# hltb_id
# 38           1181
# 50             37
# 66            646
# 79              4
# 95             26
# ...           ...
# 37895        6795
# 37905        1014
# 37940          64
# 37950        3665
# 37972          16
#
# [2161 rows x 14 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(df)
plt.savefig("pairplot.png")
# Out:
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\rapha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt
plt.savefig("pairplot.png")
