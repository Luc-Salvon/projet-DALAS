# %%
import pandas as pd

df = pd.read_csv("game_data.csv")
df = df.set_index("hltb_id")

df
# Out:
#                                                      title  rating  \
# hltb_id
# 1                                     688(I) Hunter/Killer     NaN
# 27                                             007 Legends    49.0
# 32       1... 2... 3... KICK IT! (Drop That Beat Like a...    39.0
# 37                                               1000 Amps    68.0
# 38                                                10000000    73.0
# 46                                                 15 Days    44.0
# 50                  18 Wheels of Steel: American Long Haul    53.0
# 66                                                    3079    27.0
# 71                            3D Ultra MiniGolf Adventures    63.0
# 75                                               3SwitcheD    35.0
# 77                                              4 Elements    62.0
# 79                                                40 Winks    58.0
# 83                                              4x4 Hummer     NaN
# ...
